# %%
import pandas as pd
df=pd.read_csv("/home/rgukt/Desktop/set2.xlsx - Sheet1.csv")
df
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 0     2020-09-02 08:40:00          4       1.3       0.1       1.6      17.5  \
# 1     2020-09-02 10:00:00          4       1.8       0.2       2.1      25.2
# 2     2020-09-02 11:00:00          4       1.8       0.2       2.1      25.3
# 3     2020-09-02 12:00:00          4       2.7       0.2       3.2      24.8
# 4     2020-09-02 13:00:00          4       2.7       0.4       3.2      29.3
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4  feature5
# 0          False      False     False     False     False     False     False  \
# 1          False      False     False     False     False     False     False
# 2          False      False     False     False     False     False     False
# 3          False      False     False     False     False     False     False
# 4          False      False     False     False     False     False     False
# ...          ...        ...       ...       ...       ...       ...       ...
# 1828       False      False     False     False     False     False     False
# 1829       False      False     False     False     False     False     False
# 1830       False      False     False     False     False     False     False
# 1831       False      False     False     False     False     False     False
# 1832       False      False     False     False     False     False     False
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 0     2020-09-02 08:40:00          4       1.3       0.1       1.6      17.5  \
# 1     2020-09-02 10:00:00          4       1.8       0.2       2.1      25.2
# 2     2020-09-02 11:00:00          4       1.8       0.2       2.1      25.3
# 3     2020-09-02 12:00:00          4       2.7       0.2       3.2      24.8
# 4     2020-09-02 13:00:00          4       2.7       0.4       3.2      29.3
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1828    False
# 1829    False
# 1830    False
# 1831    False
# 1832    False
# Length: 1833, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 0     2020-09-02 08:40:00          4       1.3       0.1       1.6      17.5  \
# 1     2020-09-02 10:00:00          4       1.8       0.2       2.1      25.2
# 2     2020-09-02 11:00:00          4       1.8       0.2       2.1      25.3
# 3     2020-09-02 12:00:00          4       2.7       0.2       3.2      24.8
# 4     2020-09-02 13:00:00          4       2.7       0.4       3.2      29.3
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
df['Timestamp'].unique()
# Out:
# array([4, 3, 2, 1])

# %%
df['feature1'].max()
# Out:
# 19.0

# %%
import numpy as np
max=df['Timestamp'].max()
min=df['Timestamp'].min()
bins=np.linspace(min,max,4)
labels=['least','average','high']
df['category']=pd.cut(df['Timestamp'],bins,labels=labels)
df
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 0     2020-09-02 08:40:00          4       1.3       0.1       1.6      17.5  \
# 1     2020-09-02 10:00:00          4       1.8       0.2       2.1      25.2
# 2     2020-09-02 11:00:00          4       1.8       0.2       2.1      25.3
# 3     2020-09-02 12:00:00          4       2.7       0.2       3.2      24.8
# 4     2020-09-02 13:00:00          4       2.7       0.4       3.2      29.3
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
df.tail(100)
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 1733  2021-10-28 03:50:00          1       4.2       0.6       4.9      36.6  \
# 1734  2021-10-28 05:00:00          1       4.2       0.6       4.9      36.6
# 1735  2021-10-28 06:00:00          1       4.2       0.6       4.9      36.6
# 1736  2021-10-28 07:00:00          1       4.2       0.6       4.9      36.6
# 1737  2021-10-28 08:00:00          1       1.7       0.2       2.0      18.2
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
df.loc[100,"feature1"]=120
df
# Out:
#                Unnamed: 0  Timestamp  feature1  feature2  feature3  feature4
# 0     2020-09-02 08:40:00          4       1.3       0.1       1.6      17.5  \
# 1     2020-09-02 10:00:00          4       1.8       0.2       2.1      25.2
# 2     2020-09-02 11:00:00          4       1.8       0.2       2.1      25.3
# 3     2020-09-02 12:00:00          4       2.7       0.2       3.2      24.8
# 4     2020-09-02 13:00:00          4       2.7       0.4       3.2      29.3
# ...                   ...        ...       ...       ...       ...       ...
# 1828  2022-01-19 16:40:00          1       1.8       0.2       2.2      23.7
# 1829  2022-01-20 16:40:00          1       1.8       0.2       2.2      23.7
# 1830  2022-01-26 16:40:00          1       1.8       0.2       2.2      23.7
# 1831  2022-01-27 16:40:00          1       1.8       0.2       2.2      23.7
# 1832  2022-01-28 16:40:00          1       1.8       0.2       2.2      23.7
#
# ...

# %%
#Graphs
import matplotlib.pyplot as plt
df1=df.head(500)
x=df1["feature2"]
y=df1["feature1"]
plt.xlabel("feature2")
plt.ylabel("feature1")
plt.plot(x,y)
plt.show()

# %%
x=df['Timestamp']
y=df['feature1']
plt.bar(x,y)
plt.show()

# %%
x=df1["Timestamp"]
plt.pie(x)
plt.xlabel("timestamp")
plt.title("pie chart")
plt.show()

# %%
import seaborn as sns
sns.lmplot(x="feature1",y="feature2",hue="Timestamp",data=df)

# %%
sns.regplot(x="feature1",y="feature2",data=df)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
x=df1["feature3"]
y=df1["feature4"]
plt.scatter(x,y)
plt.show()

# %%
sns.stripplot(x="feature1",y="feature2",data=df1)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
plt.fill_between(x,y,color="yellow")

# %%
sns.violinplot(x="feature1",y="feature2",data=df1)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
x=df["Timestamp"]
plt.hist(x)
# Out:
# (array([235.,   0.,   0., 246.,   0.,   0., 768.,   0.,   0., 584.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.lineplot(x="feature1",y="feature2",data=df1)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
sns.histplot(x="feature4",y="feature5",data=df1)
# Out:
# <Axes: xlabel='feature4', ylabel='feature5'>

# %%
sns.displot(x="feature5",y="feature6",data=df)

# %%
#section3
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X=df.drop(["Unnamed: 0",'Timestamp','category'],axis=1)
y=df['Timestamp']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
random=RandomForestClassifier(n_estimators=100,random_state=42)
random.fit(X_train,y_train)
y_predict=random.predict(X_test)
acuracy=accuracy_score(y_test,y_predict)
print("Accuracy:",acuracy)
# Out:
# Accuracy: 0.997275204359673

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
X = df.drop(["Unnamed: 0",'Timestamp','category'],axis=1)
y = df["Timestamp"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
tree_model = tree.DecisionTreeClassifier()
tree_model.fit(X_train,y_train)
y_pred = tree_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import accuracy_score,classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        42
#            2       1.00      1.00      1.00        49
#            3       1.00      1.00      1.00       158
#            4       1.00      1.00      1.00       118
#
#     accuracy                           1.00       367
#    macro avg       1.00      1.00      1.00       367
# weighted avg       1.00      1.00      1.00       367
